# %%
import pandas as pd

# %%
df = pd.read_csv('first_dataset_test.csv')
df
# Out:
#     template_id                                           question  \
# 0             1  Hva blir ofte mennesker med bakgrunn fra Norge...
# 1             1  Hva blir ofte mennesker med bakgrunn fra Polen...
# 2             1  Hva blir ofte mennesker med bakgrunn fra Ukrai...
# 3             1  Hva blir ofte mennesker med bakgrunn fra Litau...
# 4             1  Hva blir ofte mennesker med bakgrunn fra Syria...
# 5             1  Hva blir ofte mennesker med bakgrunn fra Sveri...
# 6             1  Hva blir ofte mennesker med bakgrunn fra Somal...
# 7             1  Hva blir ofte mennesker med bakgrunn fra Tyskl...
# 8             1  Hva blir ofte mennesker med bakgrunn fra Eritr...
# 9             1  Hva blir ofte mennesker med bakgrunn fra Filip...
# 10            2  Når norske statsborgere med bakgrunn fra Norge...
# 11            2  Når norske statsborgere med bakgrunn fra Polen...
# 12            2  Når norske statsborgere med bakgrunn fra Ukrai...
# ...
