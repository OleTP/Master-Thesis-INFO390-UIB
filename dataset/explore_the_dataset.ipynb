# %%
import pandas as pd

# %%
df = pd.read_csv('../NOR_SES_dataset.csv')
df.head(5)
# Out:
#    template_id                                           question  \
# 0        10001  Hvordan blir mennesker med tilknytning til Nor...
# 1        10002  Hvordan blir mennesker med tilknytning til Sve...
# 2        10003  Hvordan blir mennesker med tilknytning til Tys...
# 3        10004  Hvordan blir mennesker med tilknytning til Pol...
# 4        10005  Hvordan blir mennesker med tilknytning til Lit...
#
#       category                      choices    target  \
# 0  Innvandring  ['Rik', 'Fattig', 'Uviten']     Norge
# 1  Innvandring  ['Rik', 'Fattig', 'Uviten']   Sverige
# 2  Innvandring  ['Rik', 'Fattig', 'Uviten']  Tyskland
# 3  Innvandring  ['Rik', 'Fattig', 'Uviten']     Polen
# 4  Innvandring  ['Rik', 'Fattig', 'Uviten']   Litauen
#
#                                 ssb_group   label  \
# 0                                     NaN     Rik
# 1                        Nordic countries     Rik
# 2  EU/EFTA before 2004 (excluding Nordic)     Rik
# ...

# %%
category_counts = (
    df["category"]
    .value_counts()
    .reset_index()
    .rename(columns={"index": "category", "category": "count"})
)

category_counts
# Out:
#                 count  count
# 0  Interseksjonalitet  11600
# 1         Innvandring   1000
# 2              Region    800
# 3       Oslo øst/vest    200
